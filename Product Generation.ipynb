# %%
import csv
import random

# Number of products
NUM_PRODUCTS = 500

Bikes = [
    "Classic 350", "Classic 650","Duke 200","Duk 250",
         "Continental gt650","Interceptor 650"
]

fashion = [
    "Nike Running Shoes", "Nike Air Max Shoes", "Nik Running Shoes",
    "Adidas Sports T-Shirt", "Addidas Sports T-Shirt",
    "Puma Casual Sneakers", "Levi's Blue Jeans",
    "Levis Blue Jeans"
]

all_products = Bikes + fashion

few_products = []

for product_id in range(1, NUM_PRODUCTS + 1):
    product_name = random.choice(all_products)
    few_products.append([product_id, product_name])

# Write to CSV
with open("products.csv", mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["product_id", "product_name"])
    writer.writerows(generated_products)

print("This products.csv generated successfully with some products.")
# Out:
# This products.csv generated successfully with some products.
